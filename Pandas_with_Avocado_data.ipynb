# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Creating DataFrames
# From a list of dictionaries (constructed row by row)

# %%
list_of_dict=[{'genus':'bambusa','species':'bambos','height':45,'diameter':10},
              {'genus':'bambusa','species':'wamin','height':15,'diameter':5}]

# %%
list_of_dict
# Out:
# [{'genus': 'bambusa', 'species': 'bambos', 'height': 45, 'diameter': 10},
#  {'genus': 'bambusa', 'species': 'wamin', 'height': 15, 'diameter': 5}]

# %%
new_dataframe=pd.DataFrame(list_of_dict)

# %%
new_dataframe
# Out:
#      genus species  height  diameter
# 0  bambusa  bambos      45        10
# 1  bambusa   wamin      15         5

# %%
dict_of_lists = { 
     "name": ["Ginger", "Scout"], 
     "breed": ["Dachshund", "Dalmatian"], 
     "height_cm": [22, 59], 
     "weight_kg": [10, 25], 
     "date_of_birth": ["2019-03-14","2019-05-09"]  } 
new_dogs = pd.DataFrame(dict_of_lists) 
new_dogs
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %% [markdown]
# # Reading and writing CSVs
# CSV = comma-separated values
# Designed for DataFrame-like data
# Most database and spreadsheet programs can use them or create them

# %%
avocado=pd.read_csv(r'C:\Users\ankus\OneDrive\Desktop\Naresh IT\22nd_April\avocado.csv')

# %%
avocado.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
avocado=avocado.iloc[:,1:]
avocado.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
# To write a CSV file function dataframe.to_csv(FILE_NAME)
avocado.to_csv('next1.csv')

# %% [markdown]
# # Some useful pandas function

# %%
#1. head()- Top 5 row, head(x)- top x number of rows
avocado.head(2)
# Out:
#          Date  AveragePrice  Total Volume     4046      4225   4770  \
# 0  2015-12-27          1.33      64236.62  1036.74  54454.85  48.16
# 1  2015-12-20          1.35      54876.98   674.28  44638.81  58.33
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany

# %%
#2. trai()- last rows, tail(x)- last x number of rows

# %%
avocado.tail(2)
# Out:
#              Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18247  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
# Shape - rows and column in data frame
avocado.shape
# Out:
# (18249, 13)

# %%
# .info() is used to get a concise summary of the DataFrame
avocado.info() # Ecah column name with its types 
# Object is not useful
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
avocado.head(2)
# Out:
#          Date  AveragePrice  Total Volume     4046      4225   4770  \
# 0  2015-12-27          1.33      64236.62  1036.74  54454.85  48.16
# 1  2015-12-20          1.35      54876.98   674.28  44638.81  58.33
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany

# %% [markdown]
# # Any colulmn as index

# %%
# read CSV from using pandas and assigning Date as index of the dataframe
avocado = pd.read_csv(r"C:\Users\ankus\OneDrive\Desktop\Naresh IT\22nd_April\avocado.csv",parse_dates=True, index_col='Date')
# print the first few rows of the dataframe
avocado.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# 2015-12-20  conventional  2015  Albany
# 2015-12-13  conventional  2015  Albany
# 2015-12-06  conventional  2015  Albany
# 2015-11-29  conventional  2015  Albany

# %%
# drop or remove index
avocado = avocado.reset_index(drop=True)
avocado.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0           0          1.33      64236.62  1036.74   54454.85   48.16
# 1           1          1.35      54876.98   674.28   44638.81   58.33
# 2           2          0.93     118220.22   794.70  109149.67  130.50
# 3           3          1.08      78992.15  1132.00   71976.41   72.58
# 4           4          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avocado.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
# .columns this attribute return a Numpy representation of columns in the DataFrame
avocado.columns
# Out:
# Index(['Unnamed: 0', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %% [markdown]
# # Sorting

# %%
#DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind=’quicksort’, na_position=’last’)

avocado.head(2)
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046      4225   4770  \
# 0           0          1.33      64236.62  1036.74  54454.85  48.16
# 1           1          1.35      54876.98   674.28  44638.81  58.33
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany

# %%
# sort values based on "AveragePrice" (ascending) and "year" (descending)
avocado.sort_values(["AveragePrice", "year"], ascending=[True, True])
# Out:
#        Unnamed: 0  AveragePrice  Total Volume        4046       4225  \
# 15261          43          0.44      64057.04      223.84    4748.88
# 7412           47          0.46    2200550.27  1200632.86  531226.65
# 15473          43          0.48      50890.73      717.57    4138.84
# 1716            0          0.49    1137707.43   738314.80  286858.37
# 15262          44          0.49      44024.03      252.79    4472.68
# ...           ...           ...           ...         ...        ...
# 16720          18          3.04      12656.32      419.06    4851.90
# 16055          42          3.05       2068.26     1043.83      77.36
# 14124           7          3.12      19043.80     5898.49   10039.34
# 17428          37          3.17       3018.56     1255.55      82.31
# 14125           8          3.25      16700.94     2325.93   11142.85
#
#            4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 15261      0.00    59084.32      638.68    58445.64         0.00
# 7412   18324.93   450365.83   113752.17   330583.10      6030.56
# 15473      0.00    46034.32     1385.06    44649.26         0.00
# 1716   11642.46   100891.80    70749.02    30142.78         0.00
# 15262      0.00    39298.56      600.00    38698.56         0.00
# ...         ...         ...         ...         ...          ...
# 16720    145.09     7240.27     6960.97      279.30         0.00
# 16055      0.00      947.07      926.67       20.40         0.00
# 14124      0.00     3105.97     3079.30       26.67         0.00
# 17428      0.00     1680.70     1542.22      138.48         0.00
# 14125      0.00     3232.16     3232.16        0.00         0.00
#
#                type  year             region
# 15261       organic  2017   CincinnatiDayton
# 7412   conventional  2017      PhoenixTucson
# 15473       organic  2017            Detroit
# 1716   conventional  2015      PhoenixTucson
# 15262       organic  2017   CincinnatiDayton
# ...             ...   ...                ...
# 16720       organic  2017  RaleighGreensboro
# 16055       organic  2017  MiamiFtLauderdale
# 14124       organic  2016       SanFrancisco
# 17428       organic  2017              Tampa
# 14125       organic  2016       SanFrancisco
#
# [18249 rows x 13 columns]

# %% [markdown]
# # Subsetting
# Subsetting is used to get a slice of the original dataframe

# %%
avocado['AveragePrice']
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
# Subsetting multiple columns
avocado[["AveragePrice","year"]]
# Out:
#        AveragePrice  year
# 0              1.33  2015
# 1              1.35  2015
# 2              0.93  2015
# 3              1.08  2015
# 4              1.28  2015
# ...             ...   ...
# 18244          1.63  2018
# 18245          1.71  2018
# 18246          1.87  2018
# 18247          1.93  2018
# 18248          1.62  2018
#
# [18249 rows x 2 columns]

# %%
# Subsetting row wise
# This will print only the rows with price < 1
avocado[avocado["AveragePrice"]<1]
# Out:
#        Unnamed: 0  AveragePrice  Total Volume      4046       4225    4770  \
# 2               2          0.93     118220.22    794.70  109149.67  130.50
# 6               6          0.99      83453.76   1368.92   73672.72   93.26
# 7               7          0.98     109428.33    703.75  101815.36   80.00
# 13             13          0.99     106803.39   1204.88   99409.21  154.84
# 43             43          0.99      55595.74    629.46   45633.34  181.49
# ...           ...           ...           ...       ...        ...     ...
# 17169          43          0.99     155011.12  35367.23    5175.81    5.91
# 17170          44          0.99     171145.00  34520.03    6936.39    0.00
# 17536          39          0.98     402676.23  34093.33   58330.53  207.85
# 17537          40          0.90     456645.91  36169.35   51398.72  139.55
# 17540          43          0.99     367519.17  61166.48   55123.99  126.80
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 6         8318.86     8196.81      122.05          0.0  conventional  2015
# 7         6829.22     6266.85      562.37          0.0  conventional  2015
# 13        6034.46     5888.87      145.59          0.0  conventional  2015
# 43        9151.45     8986.06      165.39          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 17169   114462.17    95379.07    19083.10          0.0       organic  2017
# 17170   129688.58   117252.31    12436.27          0.0       organic  2017
# 17536   310044.52   155701.41   154343.11          0.0       organic  2017
# 17537   368938.29   152159.53   216778.76          0.0       organic  2017
# 17540   251101.90   112844.19   138257.71          0.0       organic  2017
#
#              region
# 2            Albany
# 6            Albany
# 7            Albany
# 13           Albany
# 43           Albany
# ...             ...
# 17169  SouthCentral
# 17170  SouthCentral
# 17536          West
# 17537          West
# 17540          West
#
# [2796 rows x 13 columns]

# %% [markdown]
# # Subsetting based on multiple conditions
# You can use the logical operators to define a complex condition
#
# "&" and
# "|" or
# "~" not

# %%
#Subsetting multiple column values based on text data
avocado[(avocado.region=='West') & (avocado.type=='organic')]
# Out:
#        Unnamed: 0  AveragePrice  Total Volume      4046      4225    4770  \
# 11830           0          1.46     142710.36  29880.32  48416.71   38.63
# 11831           1          1.45     144120.63  30114.67  45111.21   38.63
# 11832           2          1.16     228520.16  29083.18  68810.09   67.91
# 11833           3          1.39     139927.17  22320.01  49596.02   61.25
# 11834           4          1.26     174210.66  22168.11  57717.17  102.49
# ...           ...           ...           ...       ...       ...     ...
# 18232           7          1.41     283378.47  22474.66  55360.49  133.41
# 18233           8          1.80     185974.53  22918.40  33051.14   93.52
# 18234           9          1.83     189317.99  27049.44  33561.32  439.47
# 18235          10          1.82     207999.67  33869.12  47435.14  433.52
# 18236          11          1.48     297190.60  34734.97  62967.74  157.77
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year region
# 11830    64374.70    17464.54    46910.16         0.00  organic  2015   West
# 11831    68856.12    12937.47    55918.65         0.00  organic  2015   West
# 11832   130558.98    28892.20   101666.78         0.00  organic  2015   West
# 11833    67949.89     3623.32    64326.57         0.00  organic  2015   West
# 11834    94222.89     1722.92    92499.97         0.00  organic  2015   West
# ...           ...         ...         ...          ...      ...   ...    ...
# 18232   205409.91    70232.59   134666.91       510.41  organic  2018   West
# 18233   129911.47    77822.23    51986.86       102.38  organic  2018   West
# 18234   128267.76    76091.99    51947.50       228.27  organic  2018   West
# 18235   126261.89    89115.78    37133.99        12.12  organic  2018   West
# 18236   199330.12   103761.55    95544.39        24.18  organic  2018   West
#
# [169 rows x 13 columns]

# %%
#Subsetting multiple column values based on text data
avocado[(avocado.region=='West') | (avocado.type=='organic') |(avocado.year==2015)]
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [12048 rows x 13 columns]

# %%
#Subsetting multiple column values based on text data
avocado[(avocado.region=='West') & (avocado.type=='organic') &(avocado.year==2015)& (avocado.AveragePrice<=1.3)]
# Out:
#        Unnamed: 0  AveragePrice  Total Volume       4046       4225    4770  \
# 11832           2          1.16     228520.16   29083.18   68810.09   67.91
# 11834           4          1.26     174210.66   22168.11   57717.17  102.49
# 11835           5          1.29     223979.09   28451.14   77160.23  123.89
# 11838           8          1.23     242525.92   37553.46   78353.97  535.26
# 11864          34          1.24     378778.68  208996.22  121444.88  242.71
# 11865          35          1.27     389892.07  183001.34  163634.35  524.42
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year region
# 11832   130558.98    28892.20   101666.78          0.0  organic  2015   West
# 11834    94222.89     1722.92    92499.97          0.0  organic  2015   West
# 11835   118243.83     2251.17   115992.66          0.0  organic  2015   West
# 11838   126083.23    25674.73   100408.50          0.0  organic  2015   West
# 11864    48094.87    10896.11    37198.76          0.0  organic  2015   West
# 11865    42731.96     9833.16    32898.80          0.0  organic  2015   West

# %% [markdown]
# # Subsetting using .isin()
# isin() method helps in selecting rows with having a particular(or Multiple) value in a particular column
#
# Syntax: DataFrame.isin(values)

# %%
avocado[avocado['region'].isin(['West'])]
# Out:
#        Unnamed: 0  AveragePrice  Total Volume        4046        4225  \
# 2704            0          0.83    5291979.63  2038443.68  1717599.45
# 2705            1          0.88    4737649.03  2017331.24  1314711.00
# 2706            2          0.85    4899439.92  1798995.46  1596329.01
# 2707            3          0.75    6202513.84  2097720.52  2051392.83
# 2708            4          0.99    3719603.21  1461861.54  1216811.00
# ...           ...           ...           ...         ...         ...
# 18232           7          1.41     283378.47    22474.66    55360.49
# 18233           8          1.80     185974.53    22918.40    33051.14
# 18234           9          1.83     189317.99    27049.44    33561.32
# 18235          10          1.82     207999.67    33869.12    47435.14
# 18236          11          1.48     297190.60    34734.97    62967.74
#
#             4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 2704   125254.82  1410681.68   838267.79   567269.76      5144.13
# 2705   130849.60  1274757.19   843691.13   417746.45     13319.61
# 2706   134101.62  1370013.83   851506.76   517936.19       570.88
# 2707   107568.34  1945832.15  1360760.83   582846.33      2224.99
# 2708   104219.76   936710.91   688674.00   247318.15       718.76
# ...          ...         ...         ...         ...          ...
# 18232     133.41   205409.91    70232.59   134666.91       510.41
# 18233      93.52   129911.47    77822.23    51986.86       102.38
# 18234     439.47   128267.76    76091.99    51947.50       228.27
# 18235     433.52   126261.89    89115.78    37133.99        12.12
# 18236     157.77   199330.12   103761.55    95544.39        24.18
#
#                type  year region
# 2704   conventional  2015   West
# 2705   conventional  2015   West
# 2706   conventional  2015   West
# 2707   conventional  2015   West
# 2708   conventional  2015   West
# ...             ...   ...    ...
# 18232       organic  2018   West
# 18233       organic  2018   West
# 18234       organic  2018   West
# 18235       organic  2018   West
# 18236       organic  2018   West
#
# [338 rows x 13 columns]

# %%
avocado[avocado.region.isin(['West'])]
# Out:
#        Unnamed: 0  AveragePrice  Total Volume        4046        4225  \
# 2704            0          0.83    5291979.63  2038443.68  1717599.45
# 2705            1          0.88    4737649.03  2017331.24  1314711.00
# 2706            2          0.85    4899439.92  1798995.46  1596329.01
# 2707            3          0.75    6202513.84  2097720.52  2051392.83
# 2708            4          0.99    3719603.21  1461861.54  1216811.00
# ...           ...           ...           ...         ...         ...
# 18232           7          1.41     283378.47    22474.66    55360.49
# 18233           8          1.80     185974.53    22918.40    33051.14
# 18234           9          1.83     189317.99    27049.44    33561.32
# 18235          10          1.82     207999.67    33869.12    47435.14
# 18236          11          1.48     297190.60    34734.97    62967.74
#
#             4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 2704   125254.82  1410681.68   838267.79   567269.76      5144.13
# 2705   130849.60  1274757.19   843691.13   417746.45     13319.61
# 2706   134101.62  1370013.83   851506.76   517936.19       570.88
# 2707   107568.34  1945832.15  1360760.83   582846.33      2224.99
# 2708   104219.76   936710.91   688674.00   247318.15       718.76
# ...          ...         ...         ...         ...          ...
# 18232     133.41   205409.91    70232.59   134666.91       510.41
# 18233      93.52   129911.47    77822.23    51986.86       102.38
# 18234     439.47   128267.76    76091.99    51947.50       228.27
# 18235     433.52   126261.89    89115.78    37133.99        12.12
# 18236     157.77   199330.12   103761.55    95544.39        24.18
#
#                type  year region
# 2704   conventional  2015   West
# 2705   conventional  2015   West
# 2706   conventional  2015   West
# 2707   conventional  2015   West
# 2708   conventional  2015   West
# ...             ...   ...    ...
# 18232       organic  2018   West
# 18233       organic  2018   West
# 18234       organic  2018   West
# 18235       organic  2018   West
# 18236       organic  2018   West
#
# [338 rows x 13 columns]

# %% [markdown]
# # Detecting missing values .isna()
# .isna() is a method used to find is there exist any NaN values in the DataFrame
#
# It will give a True bool value if a cell has a NaN value

# %%
avocado.isna()
# Out:
#        Unnamed: 0  AveragePrice  Total Volume   4046   4225   4770  \
# 0           False         False         False  False  False  False
# 1           False         False         False  False  False  False
# 2           False         False         False  False  False  False
# 3           False         False         False  False  False  False
# 4           False         False         False  False  False  False
# ...           ...           ...           ...    ...    ...    ...
# 18244       False         False         False  False  False  False
# 18245       False         False         False  False  False  False
# 18246       False         False         False  False  False  False
# 18247       False         False         False  False  False  False
# 18248       False         False         False  False  False  False
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags   type   year  region
# 0           False       False       False        False  False  False   False
# 1           False       False       False        False  False  False   False
# 2           False       False       False        False  False  False   False
# 3           False       False       False        False  False  False   False
# 4           False       False       False        False  False  False   False
# ...           ...         ...         ...          ...    ...    ...     ...
# 18244       False       False       False        False  False  False   False
# 18245       False       False       False        False  False  False   False
# 18246       False       False       False        False  False  False   False
# 18247       False       False       False        False  False  False   False
# 18248       False       False       False        False  False  False   False
#
# [18249 rows x 13 columns]

# %%
avocado.isna()
# Out:
#        Unnamed: 0  AveragePrice  Total Volume   4046   4225   4770  \
# 0           False         False         False  False  False  False
# 1           False         False         False  False  False  False
# 2           False         False         False  False  False  False
# 3           False         False         False  False  False  False
# 4           False         False         False  False  False  False
# ...           ...           ...           ...    ...    ...    ...
# 18244       False         False         False  False  False  False
# 18245       False         False         False  False  False  False
# 18246       False         False         False  False  False  False
# 18247       False         False         False  False  False  False
# 18248       False         False         False  False  False  False
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags   type   year  region
# 0           False       False       False        False  False  False   False
# 1           False       False       False        False  False  False   False
# 2           False       False       False        False  False  False   False
# 3           False       False       False        False  False  False   False
# 4           False       False       False        False  False  False   False
# ...           ...         ...         ...          ...    ...    ...     ...
# 18244       False       False       False        False  False  False   False
# 18245       False       False       False        False  False  False   False
# 18246       False       False       False        False  False  False   False
# 18247       False       False       False        False  False  False   False
# 18248       False       False       False        False  False  False   False
#
# [18249 rows x 13 columns]

# %%
avocado.isna().any()
# Out:
# Unnamed: 0      False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %% [markdown]
# # Counting missing values

# %%
avocado.isna().sum()
# Out:
# Unnamed: 0      0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# # Removing missing values
# Drop NaN .dropna()
# Fill NaN with value x .fillna(x)

# %%
avocado.dropna()

# ****  OR  ****

meanVal = avocado["AveragePrice"].mean()
avocado.fillna(meanVal)
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %% [markdown]
# # Adding a new column
# It can easily be done using the [ ] brackets
#
# Lets add a new column to our dataframe called New_Avg_Price

# %%
avocado['New_Avg_Price']=avocado['AveragePrice']*100
avocado.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0           0          1.33      64236.62  1036.74   54454.85   48.16
# 1           1          1.35      54876.98   674.28   44638.81   58.33
# 2           2          0.93     118220.22   794.70  109149.67  130.50
# 3           3          1.08      78992.15  1132.00   71976.41   72.58
# 4           4          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  New_Avg_Price
# 0  Albany          133.0
# 1  Albany          135.0
# 2  Albany           93.0
# 3  Albany          108.0
# 4  Albany          128.0

# %% [markdown]
# # Deleting columns in DataFrame .drop(lst,axis = 1)
# dataFrame.drop('COLUMN_NAME',inplace=True, axis = 1)
#
# the first parameter is a list of columns to be deleted
# axis = 1 means delete column
# axis = 0 means delete row

# %%
avocado.drop("New_Avg_Price",inplace=True,axis = 1)
avocado.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0           0          1.33      64236.62  1036.74   54454.85   48.16
# 1           1          1.35      54876.98   674.28   44638.81   58.33
# 2           2          0.93     118220.22   794.70  109149.67  130.50
# 3           3          1.08      78992.15  1132.00   71976.41   72.58
# 4           4          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avocado.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0           0          1.33      64236.62  1036.74   54454.85   48.16
# 1           1          1.35      54876.98   674.28   44638.81   58.33
# 2           2          0.93     118220.22   794.70  109149.67  130.50
# 3           3          1.08      78992.15  1132.00   71976.41   72.58
# 4           4          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
temp=avocado.drop_duplicates(subset=["year"])
temp.head()
# Out:
#       Unnamed: 0  AveragePrice  Total Volume      4046       4225    4770  \
# 0              0          1.33      64236.62   1036.74   54454.85   48.16
# 2808           0          1.52      73341.73   3202.39   58280.33  426.92
# 5616           0          1.47     113514.42   2622.70  101135.53   20.25
# 8478           0          1.57     149396.50  16361.69  109045.03   65.45
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0        8696.87     8603.62       93.25         0.00  conventional  2015
# 2808    11432.09    11017.32      411.83         2.94  conventional  2016
# 5616     9735.94     5556.98     4178.96         0.00  conventional  2017
# 8478    23924.33    19273.80     4270.53       380.00  conventional  2018
#
#       region
# 0     Albany
# 2808  Albany
# 5616  Albany
# 8478  Albany

# %% [markdown]
# # Count categorical data .value_counts()

# %%
avocado['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
avocado['year'].value_counts(sort=True, ascending=True)
# Out:
# 2018    1296
# 2015    5615
# 2016    5616
# 2017    5722
# Name: year, dtype: int64

# %% [markdown]
# # Grouped summaries .groupby(col)
# This function will group similar categories into one and then we can perform some summary statistics
# ##Syntax: DataFrame.groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True, squeeze=False, **kwargs)

# %%
avocado.groupby(['year','type'])["AveragePrice"].agg([min,max,np.mean,np.median])
# Out:
#                     min   max      mean  median
# year type
# 2015 conventional  0.49  1.59  1.077963    1.08
#      organic       0.81  2.79  1.673324    1.67
# 2016 conventional  0.51  2.20  1.105595    1.08
#      organic       0.58  3.25  1.571684    1.53
# 2017 conventional  0.46  2.22  1.294888    1.30
#      organic       0.44  3.17  1.735521    1.72
# 2018 conventional  0.56  1.74  1.127886    1.14
#      organic       1.01  2.30  1.567176    1.55

# %% [markdown]
# # Pivot table
# A pivot table is a table of statistics that summarizes the data of a more extensive table.

# %%
# this is the same table we build in the previous cell but using pivot table
avocado.pivot_table(index=["year","type"], aggfunc=[min,max,np.mean,np.median], values="AveragePrice")
# Out:
#                            min          max         mean       median
#                   AveragePrice AveragePrice AveragePrice AveragePrice
# year type
# 2015 conventional         0.49         1.59     1.077963         1.08
#      organic              0.81         2.79     1.673324         1.67
# 2016 conventional         0.51         2.20     1.105595         1.08
#      organic              0.58         3.25     1.571684         1.53
# 2017 conventional         0.46         2.22     1.294888         1.30
#      organic              0.44         3.17     1.735521         1.72
# 2018 conventional         0.56         1.74     1.127886         1.14
#      organic              1.01         2.30     1.567176         1.55

# %%
avocado.head(1)
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046      4225   4770  \
# 0           0          1.33      64236.62  1036.74  54454.85  48.16
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany

# %% [markdown]
# # Explicit indexes
# Indexes make subsetting simpler using .loc and .iloc

# %%
regionIndex = avocado.set_index(["region"])
regionIndex
# Out:
#                   Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# region
# Albany                     0          1.33      64236.62  1036.74   54454.85
# Albany                     1          1.35      54876.98   674.28   44638.81
# Albany                     2          0.93     118220.22   794.70  109149.67
# Albany                     3          1.08      78992.15  1132.00   71976.41
# Albany                     4          1.28      51039.60   941.48   43838.39
# ...                      ...           ...           ...      ...        ...
# WestTexNewMexico           7          1.63      17074.83  2046.96    1529.20
# WestTexNewMexico           8          1.71      13888.04  1191.70    3431.50
# WestTexNewMexico           9          1.87      13766.76  1191.92    2452.79
# WestTexNewMexico          10          1.93      16205.22  1527.63    2981.04
# WestTexNewMexico          11          1.62      17489.58  2894.77    2356.13
#
#                     4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# region
# Albany             48.16     8696.87     8603.62       93.25          0.0
# Albany             58.33     9505.56     9408.07       97.49          0.0
# Albany            130.50     8145.35     8042.21      103.14          0.0
# Albany             72.58     5811.16     5677.40      133.76          0.0
# Albany             75.78     6183.95     5986.26      197.69          0.0
# ...                  ...         ...         ...         ...          ...
# WestTexNewMexico    0.00    13498.67    13066.82      431.85          0.0
# WestTexNewMexico    0.00     9264.84     8940.04      324.80          0.0
# WestTexNewMexico  727.94     9394.11     9351.80       42.31          0.0
# WestTexNewMexico  727.01    10969.54    10919.54       50.00          0.0
# WestTexNewMexico  224.53    12014.15    11988.14       26.01          0.0
#
#                           type  year
# region
# Albany            conventional  2015
# Albany            conventional  2015
# Albany            conventional  2015
# Albany            conventional  2015
# Albany            conventional  2015
# ...                        ...   ...
# WestTexNewMexico       organic  2018
# WestTexNewMexico       organic  2018
# WestTexNewMexico       organic  2018
# WestTexNewMexico       organic  2018
# WestTexNewMexico       organic  2018
#
# [18249 rows x 12 columns]

# %%
regionIndex.loc[["Albany", "WestTexNewMexico"]]
# Out:
#                   Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# region
# Albany                     0          1.33      64236.62  1036.74   54454.85
# Albany                     1          1.35      54876.98   674.28   44638.81
# Albany                     2          0.93     118220.22   794.70  109149.67
# Albany                     3          1.08      78992.15  1132.00   71976.41
# Albany                     4          1.28      51039.60   941.48   43838.39
# ...                      ...           ...           ...      ...        ...
# WestTexNewMexico           7          1.63      17074.83  2046.96    1529.20
# WestTexNewMexico           8          1.71      13888.04  1191.70    3431.50
# WestTexNewMexico           9          1.87      13766.76  1191.92    2452.79
# WestTexNewMexico          10          1.93      16205.22  1527.63    2981.04
# WestTexNewMexico          11          1.62      17489.58  2894.77    2356.13
#
#                     4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# region
# Albany             48.16     8696.87     8603.62       93.25          0.0
# Albany             58.33     9505.56     9408.07       97.49          0.0
# Albany            130.50     8145.35     8042.21      103.14          0.0
# Albany             72.58     5811.16     5677.40      133.76          0.0
# Albany             75.78     6183.95     5986.26      197.69          0.0
# ...                  ...         ...         ...         ...          ...
# WestTexNewMexico    0.00    13498.67    13066.82      431.85          0.0
# WestTexNewMexico    0.00     9264.84     8940.04      324.80          0.0
# WestTexNewMexico  727.94     9394.11     9351.80       42.31          0.0
# WestTexNewMexico  727.01    10969.54    10919.54       50.00          0.0
# WestTexNewMexico  224.53    12014.15    11988.14       26.01          0.0
#
#                           type  year
# region
# Albany            conventional  2015
# Albany            conventional  2015
# Albany            conventional  2015
# Albany            conventional  2015
# Albany            conventional  2015
# ...                        ...   ...
# WestTexNewMexico       organic  2018
# WestTexNewMexico       organic  2018
# WestTexNewMexico       organic  2018
# WestTexNewMexico       organic  2018
# WestTexNewMexico       organic  2018
#
# [673 rows x 12 columns]

# %% [markdown]
# # Visualizing your data

# %%
avocado['AveragePrice'].hist(bins=20)
plt.show()

# %%
regionFilter = avocado.groupby("region")["AveragePrice"].mean().head(10)
regionFilter.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='region'>

# %%
plt.plot(avocado['AveragePrice'])

# %%
vis1=avocado.hist(column='AveragePrice')

# %%
vis2=avocado.boxplot(column='AveragePrice')

# %%
vis2=plt.hist(avocado.AveragePrice)

# %%
avocado.plot(x="AveragePrice", y="Total Volume", kind="scatter")
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %%
avocado.plot(x="AveragePrice", y="Total Volume", kind="bar")
# Out:
# <AxesSubplot:xlabel='AveragePrice'>
